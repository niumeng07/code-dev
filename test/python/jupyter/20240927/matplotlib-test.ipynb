# %%
import matplotlib.pyplot as plt

# 示例数据
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 创建一个图形和轴
fig, ax = plt.subplots()

# 绘制数据
ax.plot(x, y, label='数据线')

# 绘制水平线
 
# 添加图例
ax.legend()

# 添加标题和标签
ax.set_title('示例图')
ax.set_xlabel('X 轴')
ax.set_ylabel('Y 轴')

# 显示图形
plt.show()
