# %%
import pandas as pd

# %%
config_tickers = pd.DataFrame({'TICKER': "AMZN,AMZN,AAPL".split(',')})

# %%
config_tickers
# Out:
#   TICKER
# 0   AMZN
# 1   AAPL

# %%
import shutil

# %%
src_dir = '/Users/liuda/Desktop/1'
dst_dir = '/Users/liuda/Desktop/2'

shutil.copytree(src_dir, dst_dir, dirs_exist_ok=True)
# Out:
# '/Users/liuda/Desktop/2'

# %%
df = pd.read_csv("/Users/liuda/Local/data/trading/data/KOL/YTB_KOL.csv")

# %%
df[['KOL_id', 'publish_date', 'Date', 'trading_date']]
# Out:
#                KOL_id publish_date        Date trading_date
# 0        @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 1           @StockMoe   2025-02-27  2025-02-27   2025-02-27
# 2        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 3        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 4        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 5        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 6        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 7        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 8        @andyleegogo   2025-02-27  2025-02-27   2025-02-27
# 9        @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 10       @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 11       @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 12       @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 13       @USstocks168   2025-02-27  2025-02-27   2025-02-27
# 14       @USstocks168   2025-02-27  2025-02-27   2025-02-27
# ...
