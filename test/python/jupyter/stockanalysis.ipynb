# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://stockanalysis.com/trending/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="../_app/immutable/assets/0.BbRH7Pzs.css" rel="stylesheet"/>
# <link href="../_app/immutable/assets/___StockTable.s903ovau.css" rel="stylesheet"/><title>Today's Top Trending Stocks</title><!-- HEAD_svelte-1bleqvi_START --><meta content="A list of the top 20 most popular stocks today based on pageviews. The list is updated throughout the day." name="description"/><link href="https://stockanalysis.com/trending/" rel="canonical"/><meta content="Today's Top Trending Stocks" property="og:title"/><meta content="A list of the top 20 most popular stocks today based on pageviews. The list is updated throughout the day." property="og:description"/><meta content="https://stockanalysis.com/trending/" property="og:url"/><meta content="https://stockanalysis.com/img/bear-vs-bull.jpg" property="og:image"/><meta content="website" property="og:type"/><meta content="Stock Analysis" property="og:site_name"/><meta content="summary_large_image" name="twitter:card"/><meta content="@stock_analysisx" name="twitter:site"/><meta content="Today's Top Trending Stocks" name="twitter:title"/><meta content="A list of the top 20 most popular stocks today based on pageviews. The list is updated throughout the day." name="twitter:description"/><meta content="https://stockanalysis.com/img/bear-vs-bull.jpg" name="twitter:image"/><!-- HEAD_svelte-1bleqvi_END -->
# <link href="https://stockanalysis.com/favicon.ico" rel="shortcut icon">
# <link href="https://stockanalysis.com/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
# <link href="https://stockanalysis.com/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
# <link href="https://stockanalysis.com/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <script data-api="/cfa/event/" data-domain="stockanalysis.com" defer="" src="/cfa/js/script.js"></script>
# <script>
# 			window.plausible =
# 				window.plausible ||
# 				function () {
# 					;(window.plausible.q = window.plausible.q || []).push(arguments)
# 				}
# 		</script>
# <!-- Google Tag Manager -->
# <script>
# 			;(function (w, d, s, l, i) {
# 				w[l] = w[l] || []
# 				w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' })
# 				var f = d.getElementsByTagName(s)[0],
# 					j = d.createElement(s),
# 					dl = l != 'dataLayer' ? '&l=' + l : ''
# 				j.async = true
# 				j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl
# 				f.parentNode.insertBefore(j, f)
# 			})(window, document, 'script', 'dataLayer', 'GTM-TPBBBKLR')
# 		</script>
# <!-- End Google Tag Manager -->
# </link></link></link></head>
# <body data-sveltekit-preload-data="hover">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TPBBBKLR" style="display: none; visibility: hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div> <header class="sticky top-0 z-50 bg-white shadow-md dark:bg-dark-800 landscape:static landscape:lg:sticky"><div class="flex flex-row items-center gap-x-1 px-1 py-1.5 tiny:gap-x-1 tiny:px-2 xs:gap-x-3 xs:px-3 sm:py-2 lg:gap-x-4 xxl:px-4 xxxl:px-6"><a class="sr-only focus:not-sr-only" data-svelte-h="svelte-18qvitj" href="#main">Skip to main content</a> <button aria-controls="left-navigation" aria-expanded="false" aria-label="Open Menu" class="xxl:hidden"><!-- HTML_TAG_START --><svg class="h-8 w-8 cursor-pointer text-faded" fill="none" stroke="currentColor" style="max-width:40px" viewbox="0 0 24 24"><path d="M4 6h16M4 12h16M4 18h16" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></
# 	<!-- HTML_TAG_START --><svg class="-mb-px size-4 text-icon" fill="none" stroke="currentColor" style="max-width:40px" viewbox="0 0 24 24"><path d="M17.25 8.25L21 12m0 0l-3.75 3.75M21 12H3" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg><!-- HTML_TAG_END --></button> <div class="relative inline-block text-left"><button aria-label="Table options" class="controls-btn"><!-- HTML_TAG_START --><svg class="w-5 h-5" fill="none" stroke="currentColor" style="max-width:40px" viewbox="0 0 24 24"><path d="M12 5v.01M12 12v.01M12 19v.01M12 6a1 1 0 110-2 1 1 0 010 2zm0 7a1 1 0 110-2 1 1 0 010 2zm0 7a1 1 0 110-2 1 1 0 010 2z" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg><!-- HTML_TAG_END --></button> </div></div></div> <div class="styled-scrollbar bottom-scrollbar overflow-x-auto" id="main-table-wrap"><table class="symbol-table svelte-utsffj" id="main-table"><thead><tr class="svelte-utsffj"><th class="svelte-utsffj" draggable="true" id="no">No. </th><th class="sym svelte-utsffj" draggable="true" id="s">Symbol </th><th class="slw svelte-utsffj" draggable="true" id="n">Company Name </th><th class="svelte-utsffj" draggable="true" id="views"> <span class="svelte-utsffj">Views <!-- HTML_TAG_START --><svg class="mt-0.5 w-4 h-4" fill="currentColor" style="max-width:40px" viewbox="0 0 20 20"><path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path></svg><!-- HTML_TAG_END --></span> </th><th class="svelte-utsffj" draggable="true" id="marketCap">Market Cap </th><th class="svelte-utsffj" draggable="true" id="change">% Change </th><th class="svelte-utsffj" draggable="true" id="volume">Volume </th></tr></thead> <tbody><tr class="svelte-utsffj"><td class="svelte-utsffj">1</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/pltr/">PLTR</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">Palantir Technologies Inc.</td><td class="svelte-utsffj">13,723</td><td class="svelte-utsffj">249.24B</td><td class="rr svelte-utsffj">-5.17%</td><td class="svelte-utsffj">240,421,485</td> </tr><tr class="svelte-utsffj"><td class="svelte-utsffj">2</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/nvda/">NVDA</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">NVIDIA Corporation</td><td class="svelte-utsffj">10,842</td><td class="svelte-utsffj">3,431.29B</td><td class="rg svelte-utsffj">0.63%</td><td class="svelte-utsffj">142,140,364</td> </tr><tr class="svelte-utsffj"><td class="svelte-utsffj">3</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/smci/">SMCI</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">Super Micro Computer, Inc.</td><td class="svelte-utsffj">9,425</td><td class="svelte-utsffj">34.71B</td><td class="rr svelte-utsffj">-1.63%</td><td class="svelte-utsffj">180,864,222</td> </tr><tr class="svelte-utsffj"><td class="svelte-utsffj">4</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/baba/">BABA</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">Alibaba Group Holding Limited</td><td class="svelte-utsffj">6,917</td><td class="svelte-utsffj">307.33B</td><td class="rg svelte-utsffj">8.09%</td><td class="svelte-utsffj">117,017,510</td> </tr><tr class="svelte-utsffj"><td class="svelte-utsffj">5</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/wmt/">WMT</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">Walmart Inc.</td><td class="svelte-utsffj">6,517</td><td class="svelte-utsffj">780.93B</td><td class="rr svelte-utsffj">-6.53%</td><td class="svelte-utsffj">55,290,220</td> </tr><tr class="svelte-utsffj"><td class="svelte-utsffj">6</td><td class="sym svelte-utsffj"><!-- HTML_TAG_START --><a href="/stocks/tsla/">TSLA</a><!-- HTML_TAG_END --></td><td class="slw svelte-utsffj">Tesla, Inc.</td><td class="svelte-utsffj">5,091</td><td class="svelte ...
# <script>
# 				{
# 					__sveltekit_1ro2gz5 = {
# 						base: new URL("..", location).pathname.slice(0, -1)
# 					};
#
# 					const element = document.currentScript.parentElement;
#
# 					const data = [{"type":"data","data":{session:void 0,cookies:[],loc:{co:"US"},theme:void 0,hideNewsSources:[],ab:{newsletterTitle:"Market Newsletter"}},"uses":{},"slash":"always"},{"type":"data","data":{query:{type:"s",index:"stocks",main:"views",count:20,sortDirection:"desc",columns:["no","s","n","views","marketCap","change","volume"],filters:["marketCap-notzero"]},data:[{no:1,s:"PLTR",n:"Palantir Technologies Inc.",views:13723,marketCap:249241035892.62,change:-5.17,volume:240421485},{no:2,s:"NVDA",n:"NVIDIA Corporation",views:10842,marketCap:3431293900000.0005,change:.63,volume:142140364},{no:3,s:"SMCI",n:"Super Micro Computer, Inc.",views:9425,marketCap:34706453552.9,change:-1.63,volume:180864222},{no:4,s:"BABA",n:"Alibaba Group Holding Limited",views:6917,marketCap:307329401663.94,change:8.09,volume:117017510},{no:5,s:"WMT",n:"Walmart Inc.",views:6517,marketCap:780925473960.1499,change:-6.53,volume:55290220},{no:6,s:"TSLA",n:"Tesla, Inc.",views:5091,marketCap:1139933637912.8,change:-1.71,volume:45498556},{no:7,s:"XOS",n:"Xos, Inc.",views:3846,marketCap:50183400,change:99.68,volume:95770966},{no:8,s:"CELH",n:"Celsius Holdings, Inc.",views:3502,marketCap:6000352969.56,change:-2.15,volume:16574062},{no:9,s:"AMD",n:"Advanced Micro Devices, Inc.",views:3156,marketCap:185009968921.54,change:-.45,volume:27057889},{no:10,s:"MNDR",n:"Mobile-health Network Solutions",views:2932,marketCap:32418760.108799998,change:185.42,volume:447358608},{no:11,s:"MSFT",n:"Microsoft Corporation",views:2793,marketCap:3093503027450.55,change:.33,volume:22583910},{no:12,s:"WOK",n:"WORK Medical Technology Group LTD",views:2680,marketCap:19553202.28,change:-46.18,volume:114334271},{no:13,s:"INTC",n:"Intel Corporation",views:2579,marketCap:112969700000,change:1.44,volume:144286970},{no:14,s:"AMZN",n:"Amazon.com, Inc.",views:2531,marketCap:2362021917973.76,change:-1.65,volume:29774586},{no:15,s:"QBTS",n:"D-Wave Quantum Inc.",views:2212,marketCap:2151659171.9,change:13,volume:109930014},{no:16,s:"AAPL",n:"Apple Inc.",views:2130,marketCap:3692876205590,change:.39,volume:31125149},{no:17,s:"NBIS",n:"Nebius Group N.V.",views:2105,marketCap:10889766878.75,change:3.17,volume:36057955},{no:18,s:"HIMS",n:"Hims & Hers Health, Inc.",views:1887,marketCap:14509197960.74,change:-3.39,volume:30254539},{no:19,s:"HLF",n:"Herbalife Ltd.",views:1740,marketCap:811600236.74,change:42.7,volume:23873590},{no:20,s:"META",n:"Meta Platforms, Inc.",views:1696,marketCap:1760487803692.6,change:-1.27,volume:12511851}],getTrendingTimestamp:"Feb 20, 2025, 11:30 PM EST"},"uses":{"search_params":["cache-bust"]}}];
#
# 					Promise.all([
# 						import("../_app/immutable/entry/start.zNF9rz1l.js"),
# 						import("../_app/immutable/entry/app.DGNCL3QC.js")
# 					]).then(([kit, app]) => {
# 						kit.start(app, element, {
# 							node_ids: [0, 148],
# 							data,
# 							form: null,
# 							error: null
# 						});
# 					});
# 				}
# 			</script>
# </div>
# </body>
# </html>

# %%
table = soup.find('table', {'id': 'main-table'})
# 解析表格头部
headers = []
for th in table.find_all('th'):
    headers.append(th.get_text(strip=True))

# 解析表格行
rows = []
for tr in table.find_all('tr')[1:]:  # 跳过表头
    cols = tr.find_all('td')
    if len(cols) > 0:
        row = [col.get_text(strip=True) for col in cols]
        rows.append(row)

# %%
rows
# Out:
# [['1',
#   'PLTR',
#   'Palantir Technologies Inc.',
#   '13,723',
#   '249.24B',
#   '-5.17%',
#   '240,421,485'],
#  ['2',
#   'NVDA',
#   'NVIDIA Corporation',
#   '10,842',
#   '3,431.29B',
#   '0.63%',
#   '142,140,364'],
#  ['3',
#   'SMCI',
#   'Super Micro Computer, Inc.',
#   '9,425',
#   '34.71B',
#   '-1.63%',
#   '180,864,222'],
#  ['4',
#   'BABA',
#   'Alibaba Group Holding Limited',
#   '6,917',
#   '307.33B',
#   '8.09%',
#   '117,017,510'],
#  ['5', 'WMT', 'Walmart Inc.', '6,517', '780.93B', '-6.53%', '55,290,220'],
#  ['6', 'TSLA', 'Tesla, Inc.', '5,091', '1,139.93B', '-1.71%', '45,498,556'],
#  ['7', 'XOS', 'Xos, Inc.', '3,846', '50.18M', '99.68%', '95,770,966'],
#  ['8',
#   'CELH',
#   'Celsius Holdings, Inc.',
#   '3,502',
#   '6.00B',
#   '-2.15%',
#   '16,574,062'],
#  ['9',
#   'AMD',
#   'Advanced Micro Devices, Inc.',
#   '3,156',
#   '185.01B',
#   '-0.45%',
#   '27,057,889'],
#  ['10',
#   'MNDR',
#   'Mobile-health Network Solutions',
#   '2,932',
#   '32.42M',
#   '185.42%',
#   '447,358,608'],
#  ['11',
#   'MSFT',
#   'Microsoft Corporation',
#   '2,793',
#   '3,093.50B',
#   '0.33%',
#   '22,583,910'],
#  ['12',
#   'WOK',
#   'WORK Medical Technology Group LTD',
#   '2,680',
#   '19.55M',
#   '-46.18%',
#   '114,334,271'],
#  ['13',
#   'INTC',
#   'Intel Corporation',
#   '2,579',
#   '112.97B',
#   '1.44%',
#   '144,286,970'],
#  ['14',
#   'AMZN',
#   'Amazon.com, Inc.',
#   '2,531',
#   '2,362.02B',
#   '-1.65%',
#   '29,774,586'],
#  ['15',
#   'QBTS',
#   'D-Wave Quantum Inc.',
#   '2,212',
#   '2.15B',
#   '13.00%',
#   '109,930,014'],
#  ['16', 'AAPL', 'Apple Inc.', '2,130', '3,692.88B', '0.39%', '31,125,149'],
#  ['17', 'NBIS', 'Nebius Group N.V.', '2,105', '10.89B', '3.17%', '36,057,955'],
#  ['18',
#   'HIMS',
#   'Hims & Hers Health, Inc.',
#   '1,887',
#   '14.51B',
#   '-3.39%',
#   '30,254,539'],
#  ['19', 'HLF', 'Herbalife Ltd.', '1,740', '811.60M', '42.70%', '23,873,590'],
#  ['20',
#   'META',
#   'Meta Platforms, Inc.',
#   '1,696',
#   '1,760.49B',
#   '-1.27%',
#   '12,511,851']]

# %%
import pandas as pd
df = pd.DataFrame(rows, columns=headers)

# %%
df
# Out:
#    No. Symbol                       Company Name   Views Market Cap % Change  \
# 0    1   PLTR         Palantir Technologies Inc.  13,723    249.24B   -5.17%
# 1    2   NVDA                 NVIDIA Corporation  10,842  3,431.29B    0.63%
# 2    3   SMCI         Super Micro Computer, Inc.   9,425     34.71B   -1.63%
# 3    4   BABA      Alibaba Group Holding Limited   6,917    307.33B    8.09%
# 4    5    WMT                       Walmart Inc.   6,517    780.93B   -6.53%
# 5    6   TSLA                        Tesla, Inc.   5,091  1,139.93B   -1.71%
# 6    7    XOS                          Xos, Inc.   3,846     50.18M   99.68%
# 7    8   CELH             Celsius Holdings, Inc.   3,502      6.00B   -2.15%
# 8    9    AMD       Advanced Micro Devices, Inc.   3,156    185.01B   -0.45%
# 9   10   MNDR    Mobile-health Network Solutions   2,932     32.42M  185.42%
# 10  11   MSFT              Microsoft Corporation   2,793  3,093.50B    0.33%
# 11  12    WOK  WORK Medical Technology Group LTD   2,680     19.55M  -46.18%
# 12  13   INTC                  Intel Corporation   2,579    112.97B    1.44%
# 13  14   AMZN                   Amazon.com, Inc.   2,531  2,362.02B   -1.65%
# 14  15   QBTS                D-Wave Quantum Inc.   2,212      2.15B   13.00%
# 15  16   AAPL                         Apple Inc.   2,130  3,692.88B    0.39%
# 16  17   NBIS                  Nebius Group N.V.   2,105     10.89B    3.17%
# 17  18   HIMS           Hims & Hers Health, Inc.   1,887     14.51B   -3.39%
# 18  19    HLF                     Herbalife Ltd.   1,740    811.60M   42.70%
# 19  20   META               Meta Platforms, Inc.   1,696  1,760.49B   -1.27%
#
#          Volume
# 0   240,421,485
# 1   142,140,364
# 2   180,864,222
# 3   117,017,510
# 4    55,290,220
# 5    45,498,556
# 6    95,770,966
# 7    16,574,062
# 8    27,057,889
# 9   447,358,608
# 10   22,583,910
# 11  114,334,271
# 12  144,286,970
# 13   29,774,586
# 14  109,930,014
# 15   31,125,149
# 16   36,057,955
# 17   30,254,539
# 18   23,873,590
# 19   12,511,851
